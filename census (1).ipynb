# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\admin\\Downloads\\archive (6)\\population.csv")

# %%
data.head()
# Out:
#    Rank           State    Capital   Population  % of Total Population  \
# 0     1   Uttar Pradesh    Lucknow  199,812,341                  16.50
# 1     2     Maharashtra     Mumbai  112,374,333                   9.28
# 2     3           Bihar      Patna  104,099,452                   8.60
# 3     4     West Bengal    Kolkata   91,276,115                   7.54
# 4     5  Andhra Pradesh  Hyderabad   84,580,777                   6.99
#
#          Males     Females Sex Ratio  Literacy Rate (%) Rural Population  \
# 0  104,480,510  95,331,831       912              67.68      155,111,022
# 1   58,243,056  54,131,277       929              82.34       61,545,441
# 2   54,278,157  49,821,295       918              61.80       92,075,028
# 3   46,809,027  44,467,088       950              76.26       62,213,676
# 4   42,442,146  42,138,631       993              67.02       56,361,702
#
#   Urban Population Area (km*km) Density (1/km*km) Decadal Growth (%)
# ...

# %%
data.tail()
# Out:
#     Rank                        State     Capital Population  \
# 30    31                       Sikkim     Gangtok    610,577
# 31    32  Andaman and Nicobar Islands  Port Blair    380,581
# 32    33       Dadra and Nagar Haveli    Silvassa    343,709
# 33    34                Daman and Diu       Daman    243,247
# 34    35                  Lakshadweep   Kavaratti     64,473
#
#     % of Total Population    Males  Females Sex Ratio  Literacy Rate (%)  \
# 30                   0.05  323,070  287,507       890              81.42
# 31                   0.03  202,871  177,710       876              86.63
# 32                   0.03  193,760  149,949       774              76.24
# 33                   0.02  150,301   92,946       618              87.10
# 34                   0.01   33,123   31,350       946              91.85
#
#    Rural Population Urban Population Area (km*km) Density (1/km*km)  \
# 30          455,962          151,726        7,096                86
# ...

# %% [markdown]
# #how will you hide the indexes of dataset

# %%
data.style.hide_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 data.style.hide_index()
#
# AttributeError: 'Styler' object has no attribute 'hide_index'

# %%
pip install --upgrade pandas
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 2.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/11.5 MB 3.2 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.5 MB 2.9 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.5 MB 3.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.4/11.5 MB 3.2 MB/s eta 0:00:03
#    -------------- ------------------------- 4.2/11.5 MB 3.3 MB/s eta 0:00:03
#    ------------------ --------------------- 5.2/11.5 MB 3.5 MB/s eta 0:00:02
#    -------------------- ------------------- 6.0/11.5 MB 3.5 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.5 MB 3.7 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.5 MB 3.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.5 MB 3.7 MB/s eta 0:00:01
# ...

# %%
data = pd.read_csv("C:\\Users\\admin\\Downloads\\archive (6)\\population.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 data = pd.read_csv("C:\\Users\\admin\\Downloads\\archive (6)\\population.csv",index=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %% [markdown]
# data.style.set_caption("india census 2011 dataset")

# %% [markdown]
# #show the record according to the capital  : new delhi , lucknow, jaipur

# %%
data['State'].head().isin(["Lucknow","Jaipur","Delhi"])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: State, dtype: bool

# %% [markdown]
# #how many male worker are there in maharashtra

# %%
data.groupby("State").Males.sum().sort_values().head()
# Out:
# State
# Nagaland           1,024,649
# Manipur            1,290,171
# Meghalaya          1,491,832
# Tripura            1,874,376
# Uttar Pradesh    104,480,510
# Name: Males, dtype: object

# %%
data.columns
# Out:
# Index(['Rank', 'State', 'Capital', 'Population', '% of Total Population',
#        'Males', 'Females', 'Sex Ratio', 'Literacy Rate (%)',
#        'Rural Population', 'Urban Population', 'Area (km*km)',
#        'Density (1/km*km)', 'Decadal Growth (%)'],
#       dtype='object')

# %%
data.groupby("State")[["Population","Literacy Rate (%)","Area (km*km)"]].sum()
# Out:
#                               Population  Literacy Rate (%) Area (km*km)
# State
# Andaman and Nicobar Islands      380,581              86.63        8,249
# Andhra Pradesh                84,580,777              67.02      275,045
# Arunachal Pradesh              1,383,727              65.38       83,743
# Assam                         31,205,576              72.19       78,438
# Bihar                        104,099,452              61.80       94,163
# Chandigarh                     1,055,450              86.05          114
# Chhattisgarh                  25,545,198              70.28      135,191
# Dadra and Nagar Haveli           343,709              76.24          491
# Daman and Diu                    243,247              87.10          112
# Delhi                         16,787,941              86.21        1,484
# Goa                            1,458,545              88.70        3,702
# Gujarat                       60,439,692              78.03      196,024
# ...

# %%
cd "C:\Users\admin\zomatooo\plant-disease\eda
# Out:
# C:\Users\admin\zomatooo\plant-disease\eda

# %%
git init
# Out:
#   Cell In[89], line 1
#     git init
#         ^
# SyntaxError: invalid syntax
